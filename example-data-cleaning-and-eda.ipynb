# %% [markdown]
# <a href="https://www.kaggle.com/code/nickkrikota/example-data-cleaning-and-eda?scriptVersionId=160174172" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook will go through a few examples of how to clean data and perform an exploratory data analysis using a synthetic dataset.

# %%
# Import libraries

import pandas as pd
print('Imported Successfully')
# Out:
# Imported Successfully

# %% [markdown]
# This dataset was manually edited with a few examples of unclean data to practice data cleaning.

# %%
# Load the datafeframe and view shape

customers = pd.read_csv('/kaggle/input/synthetic-customer-data/customers - cleaning.csv')
customers.shape
# Out:
# (777, 10)

# %%
# Preview dataframe

customers
# Out:
#      Customer ID              Name                           Email  \
# 0              1  Kathryn Williams  kathrynwilliams@samplemail.com
# 1              2      Maxwell Meza      maxwellmeza@samplemail.com
# 2              3    Jamie Crawford    jamiecrawford@samplemail.com
# 3              4   Raven Hernandez   ravenhernandez@samplemail.com
# 4              5      Robert Brown      robertbrown@samplemail.com
# ..           ...               ...                             ...
# 772          769        Nancy Cole        nancycole@samplemail.com
# 773          770    Samuel Barrett    samuelbarrett@samplemail.com
# 774          771        Alex Hayes        alexhayes@samplemail.com
# 775          772   Roberto Kennedy   robertokennedy@samplemail.com
# 776          773       Michael Cox       michaelcox@samplemail.com
#
#        Phone Number                Street Address             City  \
# 0    (550) 269-8345              6122 Debra Court     Stewartville
# 1    (712) 706-8059              740 Bean Station    Lake Aprilton
# 2    (278) 738-1122   65114 Tracy Track Suite 604  South Sarahbury
# 3    (376) 539-3142        45083 Cunningham Drive        Jasonstad
# 4    (368) 263-0915                 3965 Jay Ford          New Ann
# ..              ...                           ...              ...
# 772  (134) 653-8529             735 Sutton Square  Lake Meganville
# 773  (289) 571-9595         53731 Fitzgerald Keys      South David
# 774  (123) 679-2096           313 Deborah Prairie         Port Joy
# 775  (852) 816-8525               48959 Kim Field      South Emily
# 776  (385) 590-1784  45192 Nguyen Shore Suite 070   New Wandaburgh
#
#               State  Zip Code         Sales Rep Subscription
# 0            Hawaii     55169  Patricia Escobar     Standard
# 1             Maine      9073     Thomas Murray     Standard
# 2      North Dakota     51657      Amber Taylor         Plus
# 3            Hawaii     13042    Ashley Collins     Standard
# 4     New Hampshire     50080   Samantha Horton         Plus
# ..              ...       ...               ...          ...
# 772    Pennsylvania     47331    Ashley Collins         Plus
# 773  North Carolina     22817      Bradley Todd     Standard
# 774      California     66171   Samantha Graham     Standard
# 775          Texas      94465    Ashley Collins     Standard
# 776       Louisiana     96407      Amber Horton     Standard
#
# [777 rows x 10 columns]

# %% [markdown]
# # Cleaning the Data

# %% [markdown]
# First let's start with looking for duplicates.

# %%
# See duplicates

duplicates = customers[customers.duplicated()]
print('Number of duplicates:', customers.duplicated().sum())
duplicates
# Out:
# Number of duplicates: 4
#      Customer ID              Name                           Email  \
# 78            78        Daisy Webb        daisywebb@samplemail.com
# 169          168    Jennifer Jones    jenniferjones@samplemail.com
# 227          225  William Gonzalez  williamgonzalez@samplemail.com
# 432          429       Jason Davis       jasondavis@samplemail.com
#
#        Phone Number                   Street Address              City  \
# 78   (941) 622-4690                1137 West Mission         Jerryport
# 169  (812) 644-5861  31820 Donald Extension Apt. 976  Lake Suzannefurt
# 227  (337) 497-9812      5950 Cooper Trail Suite 952       Ryanborough
# 432  (852) 493-9234                  93693 Mark Spur     Alexandriaton
#
#           State  Zip Code      Sales Rep Subscription
# 78     Oklahoma     27259      Tara Peck         Plus
# 169    Illinois     98408  Richard Moore      Premium
# 227      Nevada     81451   Matthew Hunt         Plus
# 432  New Jersey     90023  Benjamin Lara      Premium

# %%
# Drop duplicates

customers = customers.drop_duplicates()
customers = customers.reset_index(drop=True)
print('Number of duplicates:', customers.duplicated().sum())
# Out:
# Number of duplicates: 0

# %% [markdown]
# Now let's see if there are any missing values.

# %%
# See number of null values

customers.isna().sum()
# Out:
# Customer ID       0
# Name              0
# Email             0
# Phone Number      2
# Street Address    2
# City              0
# State             0
# Zip Code          0
# Sales Rep         0
# Subscription      0
# dtype: int64

# %% [markdown]
# Two addresses and phone numbers are missing. You could fill them out to call attention to the person in charge of keeping this data to let them know that they need to reach out to the customers and fill it out, but for now I will simply replace it with 'n/a'

# %%
# Fill in empty values with 'n/a'

customers = customers.fillna('n/a')
customers.isna().sum()
# Out:
# Customer ID       0
# Name              0
# Email             0
# Phone Number      0
# Street Address    0
# City              0
# State             0
# Zip Code          0
# Sales Rep         0
# Subscription      0
# dtype: int64

# %%
# view column names

customers.columns
# Out:
# Index(['Customer ID', 'Name', 'Email', 'Phone Number', 'Street Address',
#        'City', 'State', 'Zip Code', 'Sales Rep', 'Subscription'],
#       dtype='object')

# %% [markdown]
# Let's look at the number of unique values in each column to see if we can find some potential errors.

# %%
# See number of unique values for each column

customers.nunique()
# Out:
# Customer ID       773
# Name              770
# Email             770
# Phone Number      772
# Street Address    772
# City              750
# State              56
# Zip Code          769
# Sales Rep          30
# Subscription        3
# dtype: int64

# %%
# See list of states

customers['State'].unique()
# Out:
# array(['Hawaii', 'Maine', 'North Dakota', 'New Hampshire', 'Alabama',
#        'Washington', 'South Carolina', 'Ohio', 'New Mexico', 'Arkansas',
#        'West Virginia', 'Vermont', 'Pennsylvania', 'Wisconsin', 'Iowa',
#        'Colorado', 'Tennessee', 'Florida', 'Connecticut', 'Utah',
#        'Nebraska', 'Alaska', 'Minnesota', 'Texas', 'New York', 'Arizona',
#        'Virginia', 'North Carolina', 'Oklahoma', 'Rhode Island',
#        'Maryland', 'Missouri', 'Idaho', 'Illinois', 'Kansas',
#        'California', 'South Dakota', 'Louisiana', 'Kentucky', 'Montana',
#        'Massachusetts', 'Mississippi', 'Michigan', 'New Jersey',
#        'Indiana', 'Delaware', ' Idaho', 'Oregon', 'Wyoming', 'Georgia',
#        'Nevada', 'NY', 'Illinois ', 'NV', ' Missouri', 'Texas '],
#       dtype=object)

# %% [markdown]
# It seems like there are more than fifty unique examples of states since some of them are abbreviated and others have trailing or leading white spaces.

# %%
# Get rid of trailing and leading spaces in state names

customers['State'] = customers['State'].str.strip()
print('Number of unique states:', customers['State'].nunique())
# Out:
# Number of unique states: 52

# %%
# Replace abbreviation with full state names

customers['State'] = customers['State'].str.replace('NY', 'New York').replace('NV', 'Nevada')
print('Number of unique states:', customers['State'].nunique())
# Out:
# Number of unique states: 50

# %% [markdown]
# # Merging Dataframes

# %% [markdown]
# Now that the data is clean, let's look at how to merge different dataframes.

# %%
# Import other datasets

salesreps = pd.read_csv('/kaggle/input/synthetic-customer-data/salesreps.csv')
subs = pd.read_csv('/kaggle/input/synthetic-customer-data/subscriptions.csv')

print(salesreps.shape)
print(subs.shape)
# Out:
# (30, 3)
# (3, 3)

# %%
# View salesreps

salesreps
# Out:
#     Employee ID                Name                          Email
# 0             1         Ricky Baker         rickybaker@company.com
# 1             2       Ashley Nguyen       ashleynguyen@company.com
# 2             3    Danielle Summers    daniellesummers@company.com
# 3             4     Samantha Horton     samanthahorton@company.com
# 4             5         Paige Jones         paigejones@company.com
# 5             6           Tara Peck           tarapeck@company.com
# 6             7    Jennifer Sanchez    jennifersanchez@company.com
# 7             8        Mark Lindsey        marklindsey@company.com
# 8             9        Taylor Mason        taylormason@company.com
# 9            10       Karen Beasley       karenbeasley@company.com
# 10           11       Robin Edwards       robinedwards@company.com
# 11           12      Ashley Collins      ashleycollins@company.com
# 12           13    Patricia Escobar    patriciaescobar@company.com
# 13           14       Thomas Murray       thomasmurray@company.com
# 14           15        Bradley Todd        bradleytodd@company.com
# 15           16  Christopher Reeves  christopherreeves@company.com
# 16           17        Stephen Frey        stephenfrey@company.com
# 17           18     Samantha Graham     samanthagraham@company.com
# 18           19    Jeffrey Williams    jeffreywilliams@company.com
# 19           20        Amber Taylor        ambertaylor@company.com
# 20           21         James Brown         jamesbrown@company.com
# 21           22       Rhonda Harris       rhondaharris@company.com
# 22           23        Mark Jenkins        markjenkins@company.com
# 23           24       Thomas Campos       thomascampos@company.com
# 24           25       Richard Moore       richardmoore@company.com
# 25           26        Sarah Abbott        sarahabbott@company.com
# 26           27       Benjamin Lara       benjaminlara@company.com
# 27           28       Angela Durham       angeladurham@company.com
# 28           29        Amber Horton        amberhorton@company.com
# 29           30        Matthew Hunt        matthewhunt@company.com

# %%
subs
# Out:
#    Subscription ID Subscription  Cost
# 0                1     Standard   $99
# 1                2         Plus  $199
# 2                3      Premium  $499

# %%
# Rename columns in the salesreps dataframe to be consistent with the columns in the customers dataframe

salesreps = salesreps.rename(columns={'Name': 'Sales Rep'})
salesreps = salesreps.rename(columns={'Email': 'Sales Rep Email'})
salesreps
# Out:
#     Employee ID           Sales Rep                Sales Rep Email
# 0             1         Ricky Baker         rickybaker@company.com
# 1             2       Ashley Nguyen       ashleynguyen@company.com
# 2             3    Danielle Summers    daniellesummers@company.com
# 3             4     Samantha Horton     samanthahorton@company.com
# 4             5         Paige Jones         paigejones@company.com
# 5             6           Tara Peck           tarapeck@company.com
# 6             7    Jennifer Sanchez    jennifersanchez@company.com
# 7             8        Mark Lindsey        marklindsey@company.com
# 8             9        Taylor Mason        taylormason@company.com
# 9            10       Karen Beasley       karenbeasley@company.com
# 10           11       Robin Edwards       robinedwards@company.com
# 11           12      Ashley Collins      ashleycollins@company.com
# 12           13    Patricia Escobar    patriciaescobar@company.com
# 13           14       Thomas Murray       thomasmurray@company.com
# 14           15        Bradley Todd        bradleytodd@company.com
# 15           16  Christopher Reeves  christopherreeves@company.com
# 16           17        Stephen Frey        stephenfrey@company.com
# 17           18     Samantha Graham     samanthagraham@company.com
# 18           19    Jeffrey Williams    jeffreywilliams@company.com
# 19           20        Amber Taylor        ambertaylor@company.com
# 20           21         James Brown         jamesbrown@company.com
# 21           22       Rhonda Harris       rhondaharris@company.com
# 22           23        Mark Jenkins        markjenkins@company.com
# 23           24       Thomas Campos       thomascampos@company.com
# 24           25       Richard Moore       richardmoore@company.com
# 25           26        Sarah Abbott        sarahabbott@company.com
# 26           27       Benjamin Lara       benjaminlara@company.com
# 27           28       Angela Durham       angeladurham@company.com
# 28           29        Amber Horton        amberhorton@company.com
# 29           30        Matthew Hunt        matthewhunt@company.com

# %%
# Add salesrep emails and employee ID to the customer dataframe

customers = pd.merge(customers, salesreps, on='Sales Rep', how='left')
customers
# Out:
#      Customer ID              Name                           Email  \
# 0              1  Kathryn Williams  kathrynwilliams@samplemail.com
# 1              2      Maxwell Meza      maxwellmeza@samplemail.com
# 2              3    Jamie Crawford    jamiecrawford@samplemail.com
# 3              4   Raven Hernandez   ravenhernandez@samplemail.com
# 4              5      Robert Brown      robertbrown@samplemail.com
# ..           ...               ...                             ...
# 768          769        Nancy Cole        nancycole@samplemail.com
# 769          770    Samuel Barrett    samuelbarrett@samplemail.com
# 770          771        Alex Hayes        alexhayes@samplemail.com
# 771          772   Roberto Kennedy   robertokennedy@samplemail.com
# 772          773       Michael Cox       michaelcox@samplemail.com
#
#        Phone Number                Street Address             City  \
# 0    (550) 269-8345              6122 Debra Court     Stewartville
# 1    (712) 706-8059              740 Bean Station    Lake Aprilton
# 2    (278) 738-1122   65114 Tracy Track Suite 604  South Sarahbury
# 3    (376) 539-3142        45083 Cunningham Drive        Jasonstad
# 4    (368) 263-0915                 3965 Jay Ford          New Ann
# ..              ...                           ...              ...
# 768  (134) 653-8529             735 Sutton Square  Lake Meganville
# 769  (289) 571-9595         53731 Fitzgerald Keys      South David
# 770  (123) 679-2096           313 Deborah Prairie         Port Joy
# 771  (852) 816-8525               48959 Kim Field      South Emily
# 772  (385) 590-1784  45192 Nguyen Shore Suite 070   New Wandaburgh
#
#               State  Zip Code         Sales Rep Subscription  Employee ID  \
# 0            Hawaii     55169  Patricia Escobar     Standard           13
# 1             Maine      9073     Thomas Murray     Standard           14
# 2      North Dakota     51657      Amber Taylor         Plus           20
# 3            Hawaii     13042    Ashley Collins     Standard           12
# 4     New Hampshire     50080   Samantha Horton         Plus            4
# ..              ...       ...               ...          ...          ...
# 768    Pennsylvania     47331    Ashley Collins         Plus           12
# 769  North Carolina     22817      Bradley Todd     Standard           15
# 770      California     66171   Samantha Graham     Standard           18
# 771           Texas     94465    Ashley Collins     Standard           12
# 772       Louisiana     96407      Amber Horton     Standard           29
#
#                  Sales Rep Email
# 0    patriciaescobar@company.com
# 1       thomasmurray@company.com
# 2        ambertaylor@company.com
# 3      ashleycollins@company.com
# 4     samanthahorton@company.com
# ..                           ...
# 768    ashleycollins@company.com
# 769      bradleytodd@company.com
# 770   samanthagraham@company.com
# 771    ashleycollins@company.com
# 772      amberhorton@company.com
#
# [773 rows x 12 columns]

# %%
# Add subscription price but not ID

customers = customers.merge(subs, on='Subscription', how='left')
customers = customers.drop(columns='Subscription ID')
customers
# Out:
#      Customer ID              Name                           Email  \
# 0              1  Kathryn Williams  kathrynwilliams@samplemail.com
# 1              2      Maxwell Meza      maxwellmeza@samplemail.com
# 2              3    Jamie Crawford    jamiecrawford@samplemail.com
# 3              4   Raven Hernandez   ravenhernandez@samplemail.com
# 4              5      Robert Brown      robertbrown@samplemail.com
# ..           ...               ...                             ...
# 768          769        Nancy Cole        nancycole@samplemail.com
# 769          770    Samuel Barrett    samuelbarrett@samplemail.com
# 770          771        Alex Hayes        alexhayes@samplemail.com
# 771          772   Roberto Kennedy   robertokennedy@samplemail.com
# 772          773       Michael Cox       michaelcox@samplemail.com
#
#        Phone Number                Street Address             City  \
# 0    (550) 269-8345              6122 Debra Court     Stewartville
# 1    (712) 706-8059              740 Bean Station    Lake Aprilton
# 2    (278) 738-1122   65114 Tracy Track Suite 604  South Sarahbury
# 3    (376) 539-3142        45083 Cunningham Drive        Jasonstad
# 4    (368) 263-0915                 3965 Jay Ford          New Ann
# ..              ...                           ...              ...
# 768  (134) 653-8529             735 Sutton Square  Lake Meganville
# 769  (289) 571-9595         53731 Fitzgerald Keys      South David
# 770  (123) 679-2096           313 Deborah Prairie         Port Joy
# 771  (852) 816-8525               48959 Kim Field      South Emily
# 772  (385) 590-1784  45192 Nguyen Shore Suite 070   New Wandaburgh
#
#               State  Zip Code         Sales Rep Subscription  Employee ID  \
# 0            Hawaii     55169  Patricia Escobar     Standard           13
# 1             Maine      9073     Thomas Murray     Standard           14
# 2      North Dakota     51657      Amber Taylor         Plus           20
# 3            Hawaii     13042    Ashley Collins     Standard           12
# 4     New Hampshire     50080   Samantha Horton         Plus            4
# ..              ...       ...               ...          ...          ...
# 768    Pennsylvania     47331    Ashley Collins         Plus           12
# 769  North Carolina     22817      Bradley Todd     Standard           15
# 770      California     66171   Samantha Graham     Standard           18
# 771           Texas     94465    Ashley Collins     Standard           12
# 772       Louisiana     96407      Amber Horton     Standard           29
#
#                  Sales Rep Email  Cost
# 0    patriciaescobar@company.com   $99
# 1       thomasmurray@company.com   $99
# 2        ambertaylor@company.com  $199
# 3      ashleycollins@company.com   $99
# 4     samanthahorton@company.com  $199
# ..                           ...   ...
# 768    ashleycollins@company.com  $199
# 769      bradleytodd@company.com   $99
# 770   samanthagraham@company.com   $99
# 771    ashleycollins@company.com   $99
# 772      amberhorton@company.com   $99
#
# [773 rows x 13 columns]

# %%
# Set index to customer ID

customers = customers.set_index('Customer ID')
customers
# Out:
#                          Name                           Email    Phone Number  \
# Customer ID
# 1            Kathryn Williams  kathrynwilliams@samplemail.com  (550) 269-8345
# 2                Maxwell Meza      maxwellmeza@samplemail.com  (712) 706-8059
# 3              Jamie Crawford    jamiecrawford@samplemail.com  (278) 738-1122
# 4             Raven Hernandez   ravenhernandez@samplemail.com  (376) 539-3142
# 5                Robert Brown      robertbrown@samplemail.com  (368) 263-0915
# ...                       ...                             ...             ...
# 769                Nancy Cole        nancycole@samplemail.com  (134) 653-8529
# 770            Samuel Barrett    samuelbarrett@samplemail.com  (289) 571-9595
# 771                Alex Hayes        alexhayes@samplemail.com  (123) 679-2096
# 772           Roberto Kennedy   robertokennedy@samplemail.com  (852) 816-8525
# 773               Michael Cox       michaelcox@samplemail.com  (385) 590-1784
#
#                            Street Address             City           State  \
# Customer ID
# 1                        6122 Debra Court     Stewartville          Hawaii
# 2                        740 Bean Station    Lake Aprilton           Maine
# 3             65114 Tracy Track Suite 604  South Sarahbury    North Dakota
# 4                  45083 Cunningham Drive        Jasonstad          Hawaii
# 5                           3965 Jay Ford          New Ann   New Hampshire
# ...                                   ...              ...             ...
# 769                     735 Sutton Square  Lake Meganville    Pennsylvania
# 770                 53731 Fitzgerald Keys      South David  North Carolina
# 771                   313 Deborah Prairie         Port Joy      California
# 772                       48959 Kim Field      South Emily           Texas
# 773          45192 Nguyen Shore Suite 070   New Wandaburgh       Louisiana
#
#              Zip Code         Sales Rep Subscription  Employee ID  \
# Customer ID
# 1               55169  Patricia Escobar     Standard           13
# 2                9073     Thomas Murray     Standard           14
# 3               51657      Amber Taylor         Plus           20
# 4               13042    Ashley Collins     Standard           12
# 5               50080   Samantha Horton         Plus            4
# ...               ...               ...          ...          ...
# 769             47331    Ashley Collins         Plus           12
# 770             22817      Bradley Todd     Standard           15
# 771             66171   Samantha Graham     Standard           18
# 772             94465    Ashley Collins     Standard           12
# 773             96407      Amber Horton     Standard           29
#
#                          Sales Rep Email  Cost
# Customer ID
# 1            patriciaescobar@company.com   $99
# 2               thomasmurray@company.com   $99
# 3                ambertaylor@company.com  $199
# 4              ashleycollins@company.com   $99
# 5             samanthahorton@company.com  $199
# ...                                  ...   ...
# 769            ashleycollins@company.com  $199
# 770              bradleytodd@company.com   $99
# 771           samanthagraham@company.com   $99
# 772            ashleycollins@company.com   $99
# 773              amberhorton@company.com   $99
#
# [773 rows x 12 columns]

# %% [markdown]
# Let's make this dataframe a little bit more readable.

# %%
# Reorder the columns, drop employee ID

customers = customers[['Name', 'Email', 'Phone Number', 'Street Address', 'City', 'State', 'Zip Code', 'Sales Rep', 'Sales Rep Email', 'Subscription', 'Cost']]
customers
# Out:
#                          Name                           Email    Phone Number  \
# Customer ID
# 1            Kathryn Williams  kathrynwilliams@samplemail.com  (550) 269-8345
# 2                Maxwell Meza      maxwellmeza@samplemail.com  (712) 706-8059
# 3              Jamie Crawford    jamiecrawford@samplemail.com  (278) 738-1122
# 4             Raven Hernandez   ravenhernandez@samplemail.com  (376) 539-3142
# 5                Robert Brown      robertbrown@samplemail.com  (368) 263-0915
# ...                       ...                             ...             ...
# 769                Nancy Cole        nancycole@samplemail.com  (134) 653-8529
# 770            Samuel Barrett    samuelbarrett@samplemail.com  (289) 571-9595
# 771                Alex Hayes        alexhayes@samplemail.com  (123) 679-2096
# 772           Roberto Kennedy   robertokennedy@samplemail.com  (852) 816-8525
# 773               Michael Cox       michaelcox@samplemail.com  (385) 590-1784
#
#                            Street Address             City           State  \
# Customer ID
# 1                        6122 Debra Court     Stewartville          Hawaii
# 2                        740 Bean Station    Lake Aprilton           Maine
# 3             65114 Tracy Track Suite 604  South Sarahbury    North Dakota
# 4                  45083 Cunningham Drive        Jasonstad          Hawaii
# 5                           3965 Jay Ford          New Ann   New Hampshire
# ...                                   ...              ...             ...
# 769                     735 Sutton Square  Lake Meganville    Pennsylvania
# 770                 53731 Fitzgerald Keys      South David  North Carolina
# 771                   313 Deborah Prairie         Port Joy      California
# 772                       48959 Kim Field      South Emily           Texas
# 773          45192 Nguyen Shore Suite 070   New Wandaburgh       Louisiana
#
#              Zip Code         Sales Rep              Sales Rep Email  \
# Customer ID
# 1               55169  Patricia Escobar  patriciaescobar@company.com
# 2                9073     Thomas Murray     thomasmurray@company.com
# 3               51657      Amber Taylor      ambertaylor@company.com
# 4               13042    Ashley Collins    ashleycollins@company.com
# 5               50080   Samantha Horton   samanthahorton@company.com
# ...               ...               ...                          ...
# 769             47331    Ashley Collins    ashleycollins@company.com
# 770             22817      Bradley Todd      bradleytodd@company.com
# 771             66171   Samantha Graham   samanthagraham@company.com
# 772             94465    Ashley Collins    ashleycollins@company.com
# 773             96407      Amber Horton      amberhorton@company.com
#
#             Subscription  Cost
# Customer ID
# 1               Standard   $99
# 2               Standard   $99
# 3                   Plus  $199
# 4               Standard   $99
# 5                   Plus  $199
# ...                  ...   ...
# 769                 Plus  $199
# 770             Standard   $99
# 771             Standard   $99
# 772             Standard   $99
# 773             Standard   $99
#
# [773 rows x 11 columns]

# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# What financial information could we potentially get from customer data?

# %%
# Convert cost to an integer to perform revenue calculations

customers['Cost'] = customers['Cost'].str.replace('$', '')
customers['Cost'] = customers['Cost'].astype(int)
customers
# Out:
# /tmp/ipykernel_19/2739454861.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['Cost'] = customers['Cost'].str.replace('$', '')
# /tmp/ipykernel_19/2739454861.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers['Cost'] = customers['Cost'].astype(int)
#                          Name                           Email    Phone Number  \
# Customer ID
# 1            Kathryn Williams  kathrynwilliams@samplemail.com  (550) 269-8345
# 2                Maxwell Meza      maxwellmeza@samplemail.com  (712) 706-8059
# 3              Jamie Crawford    jamiecrawford@samplemail.com  (278) 738-1122
# 4             Raven Hernandez   ravenhernandez@samplemail.com  (376) 539-3142
# 5                Robert Brown      robertbrown@samplemail.com  (368) 263-0915
# ...                       ...                             ...             ...
# 769                Nancy Cole        nancycole@samplemail.com  (134) 653-8529
# 770            Samuel Barrett    samuelbarrett@samplemail.com  (289) 571-9595
# 771                Alex Hayes        alexhayes@samplemail.com  (123) 679-2096
# 772           Roberto Kennedy   robertokennedy@samplemail.com  (852) 816-8525
# 773               Michael Cox       michaelcox@samplemail.com  (385) 590-1784
#
#                            Street Address             City           State  \
# Customer ID
# 1                        6122 Debra Court     Stewartville          Hawaii
# 2                        740 Bean Station    Lake Aprilton           Maine
# 3             65114 Tracy Track Suite 604  South Sarahbury    North Dakota
# 4                  45083 Cunningham Drive        Jasonstad          Hawaii
# 5                           3965 Jay Ford          New Ann   New Hampshire
# ...                                   ...              ...             ...
# 769                     735 Sutton Square  Lake Meganville    Pennsylvania
# 770                 53731 Fitzgerald Keys      South David  North Carolina
# 771                   313 Deborah Prairie         Port Joy      California
# 772                       48959 Kim Field      South Emily           Texas
# 773          45192 Nguyen Shore Suite 070   New Wandaburgh       Louisiana
#
#              Zip Code         Sales Rep              Sales Rep Email  \
# Customer ID
# 1               55169  Patricia Escobar  patriciaescobar@company.com
# 2                9073     Thomas Murray     thomasmurray@company.com
# 3               51657      Amber Taylor      ambertaylor@company.com
# 4               13042    Ashley Collins    ashleycollins@company.com
# 5               50080   Samantha Horton   samanthahorton@company.com
# ...               ...               ...                          ...
# 769             47331    Ashley Collins    ashleycollins@company.com
# 770             22817      Bradley Todd      bradleytodd@company.com
# 771             66171   Samantha Graham   samanthagraham@company.com
# 772             94465    Ashley Collins    ashleycollins@company.com
# 773             96407      Amber Horton      amberhorton@company.com
#
#             Subscription  Cost
# Customer ID
# 1               Standard    99
# 2               Standard    99
# 3                   Plus   199
# 4               Standard    99
# 5                   Plus   199
# ...                  ...   ...
# 769                 Plus   199
# 770             Standard    99
# 771             Standard    99
# 772             Standard    99
# 773             Standard    99
#
# [773 rows x 11 columns]

# %%
# Calculate revenue from the state of Louisiana

LA = customers[customers['State'] == 'Louisiana']
print('Total revenue from the state of Louisiana: $',sum(LA['Cost']))
LA
# Out:
# Total revenue from the state of Louisiana: $ 2688
#                             Name                              Email  \
# Customer ID
# 71           Christopher Collins  christophercollins@samplemail.com
# 269                 David Oneill         davidoneill@samplemail.com
# 330               Tonya Martinez       tonyamartinez@samplemail.com
# 351             Caitlin Buchanan     caitlinbuchanan@samplemail.com
# 355                  Rita Jordan          ritajordan@samplemail.com
# 440                  Karl Morris          karlmorris@samplemail.com
# 458                 Todd Andrews         toddandrews@samplemail.com
# 484                Jane Gonzales        janegonzales@samplemail.com
# 490                   Darren Orr           darrenorr@samplemail.com
# 565                  Jerry Lopez          jerrylopez@samplemail.com
# 621                Karen Wilkins        karenwilkins@samplemail.com
# 773                  Michael Cox          michaelcox@samplemail.com
#
#                Phone Number                     Street Address  \
# Customer ID
# 71           (143) 452-8346     72624 Matthew Estate Suite 803
# 269          (601) 256-3942                   877 Crystal Burg
# 330          (136) 734-6774       63854 Jason Springs Apt. 747
# 351          (434) 619-4642        6952 Morris Spring Apt. 723
# 355          (674) 192-8769                 663 Andrade Street
# 440          (653) 751-8821          337 Ashlee Ports Apt. 973
# 458          (047) 380-7700                                n/a
# 484          (418) 690-8230                 1836 Shelby Groves
# 490          (937) 711-2464                2958 Phillips Haven
# 565          (189) 505-9975                  01828 Brown Field
# 621          (117) 206-5964  99718 Phillips Mountains Apt. 943
# 773          (385) 590-1784       45192 Nguyen Shore Suite 070
#
#                           City      State  Zip Code           Sales Rep  \
# Customer ID
# 71           Port Annettehaven  Louisiana      5285       Richard Moore
# 269                  Louisport  Louisiana     67619        Stephen Frey
# 330              South Theresa  Louisiana     19852    Jeffrey Williams
# 351                Sharonmouth  Louisiana     37093         Ricky Baker
# 355             New Donnamouth  Louisiana     68291       Angela Durham
# 440               Port Melanie  Louisiana     49558         Ricky Baker
# 458               Stevensmouth  Louisiana     70890           Tara Peck
# 484                   Bassport  Louisiana     25282  Christopher Reeves
# 490           West Jessicastad  Louisiana     25674    Jennifer Sanchez
# 565                  Reyesfort  Louisiana     48340       Angela Durham
# 621                   Cainview  Louisiana     98144     Samantha Graham
# 773             New Wandaburgh  Louisiana     96407        Amber Horton
#
#                            Sales Rep Email Subscription  Cost
# Customer ID
# 71                richardmoore@company.com         Plus   199
# 269                stephenfrey@company.com         Plus   199
# 330            jeffreywilliams@company.com      Premium   499
# 351                 rickybaker@company.com         Plus   199
# 355               angeladurham@company.com         Plus   199
# 440                 rickybaker@company.com         Plus   199
# 458                   tarapeck@company.com         Plus   199
# 484          christopherreeves@company.com     Standard    99
# 490            jennifersanchez@company.com     Standard    99
# 565               angeladurham@company.com         Plus   199
# 621             samanthagraham@company.com      Premium   499
# 773                amberhorton@company.com     Standard    99

# %%
# Calculate revenue from customers assigned to Bradley Todd

BT = customers[customers['Sales Rep'] == 'Bradley Todd']
print('Total revenue from customers assigned to Bradley Todd: $', sum(BT['Cost']))
BT
# Out:
# Total revenue from customers assigned to Bradley Todd: $ 5583
#                              Name                               Email  \
# Customer ID
# 50                   Kenneth Owen          kennethowen@samplemail.com
# 86                   James Wilson          jameswilson@samplemail.com
# 132                Jenna Gonzales        jennagonzales@samplemail.com
# 140                 Jerry Francis         jerryfrancis@samplemail.com
# 190                  Judy Sanchez          judysanchez@samplemail.com
# 210                    Kurt Stone            kurtstone@samplemail.com
# 308                Michael Dawson        michaeldawson@samplemail.com
# 378          Christopher Cantrell  christophercantrell@samplemail.com
# 483                  Justin Baker          justinbaker@samplemail.com
# 511                   Tammy Davis           tammydavis@samplemail.com
# 530                  Michael Ward          michaelward@samplemail.com
# 582               Patrick Johnson       patrickjohnson@samplemail.com
# 616            Benjamin Jones Jr.     benjaminjonesjr.@samplemail.com
# 660                Amanda Johnson        amandajohnson@samplemail.com
# 710             Devin Leblanc Jr.      devinleblancjr.@samplemail.com
# 726               Sabrina Solomon       sabrinasolomon@samplemail.com
# 770                Samuel Barrett        samuelbarrett@samplemail.com
#
#                Phone Number                    Street Address  \
# Customer ID
# 50           (612) 151-0808  40721 Castro Throughway Apt. 638
# 86           (997) 421-7483                  407 Diane Meadow
# 132          (285) 361-3692       599 Browning Isle Suite 770
# 140          (957) 161-5252               39749 Julie Highway
# 190          (958) 969-1034       7908 Seth Springs Suite 857
# 210          (412) 909-0636      54945 Briana Trail Suite 878
# 308          (924) 171-1368                  720 White Forest
# 378          (785) 707-3457         3617 Bryce Wall Suite 159
# 483          (913) 674-0693                949 Jamie Mountain
# 511          (053) 070-0025    55845 Barbara Viaduct Apt. 482
# 530          (391) 909-3916               548 Jonathan Forest
# 582          (152) 519-8830       58836 Smith Track Suite 534
# 616          (821) 527-6905      1110 Nancy Overpass Apt. 541
# 660          (781) 610-7769                   888 Hardy Plaza
# 710          (199) 975-2664              43503 Franklin Point
# 726          (193) 199-1363         941 Sarah Groves Apt. 551
# 770          (289) 571-9595             53731 Fitzgerald Keys
#
#                          City           State  Zip Code     Sales Rep  \
# Customer ID
# 50            North Nancystad    Rhode Island     96120  Bradley Todd
# 86                 Harperfurt    South Dakota     70914  Bradley Todd
# 132            Hendersonburgh           Texas     86611  Bradley Todd
# 140                Joyceshire            Iowa     73709  Bradley Todd
# 190          Port Ashleyburgh   Massachusetts     44961  Bradley Todd
# 210           Cunninghammouth        New York     64413  Bradley Todd
# 308              North Yvonne       Tennessee     54524  Bradley Todd
# 378                Millerside        Maryland     86350  Bradley Todd
# 483              Whitneymouth            Ohio     69358  Bradley Todd
# 511                Lake Erica          Hawaii     30378  Bradley Todd
# 530                  East Jon        Nebraska      7740  Bradley Todd
# 582              New Margaret       Minnesota     73831  Bradley Todd
# 616                 Seanville      Washington     97977  Bradley Todd
# 660          East Raymondstad        Virginia     88482  Bradley Todd
# 710                  Westview   Massachusetts     98688  Bradley Todd
# 726          North Jaredmouth        Virginia     41477  Bradley Todd
# 770               South David  North Carolina     22817  Bradley Todd
#
#                      Sales Rep Email Subscription  Cost
# Customer ID
# 50           bradleytodd@company.com     Standard    99
# 86           bradleytodd@company.com      Premium   499
# 132          bradleytodd@company.com     Standard    99
# 140          bradleytodd@company.com         Plus   199
# 190          bradleytodd@company.com      Premium   499
# 210          bradleytodd@company.com      Premium   499
# 308          bradleytodd@company.com      Premium   499
# 378          bradleytodd@company.com         Plus   199
# 483          bradleytodd@company.com      Premium   499
# 511          bradleytodd@company.com     Standard    99
# 530          bradleytodd@company.com     Standard    99
# 582          bradleytodd@company.com      Premium   499
# 616          bradleytodd@company.com      Premium   499
# 660          bradleytodd@company.com      Premium   499
# 710          bradleytodd@company.com      Premium   499
# 726          bradleytodd@company.com         Plus   199
# 770          bradleytodd@company.com     Standard    99

# %% [markdown]
# These are just two simple examples of valuable information that could be gained from detailed and cleaned data.

# %% [markdown]
# # Conclusion

# %% [markdown]
# I hope that this was helpful. There are of course many more ways this data can be manipulated and examined to draw conclusions from it. Feel free to create and share a notebook of your own to get some practice out of this synthetic dataset.
